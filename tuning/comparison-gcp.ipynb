# %%
import sys
sys.path.append('..')

# %%
from IPython.display import display
# %config InlineBackend.figure_format='retina'

# %%
from configs.structure import Config
from environment.thieves_guardians_env import TGEnv
from tuning.comparison import read_models, play_all_pairs, compute_team_results, plot_team_aggregates, plot_boxplot

# %% [markdown]
# ## Get results

# %%
# Read models from disk
all_policies, model_names = read_models('../abc/coord')

# %% [markdown]
# ❗ Make sure all models in `models_dir` were trained on the same environment that is instantiated below:

# %%
# Re-instantiate the environment
config = Config()
config.scenario = '9x9,2v2,pacman-1'
config.state_representation = 'coordinates'

env = TGEnv(config)

# %%
# %%time
# Have all thieves play against all guardians
all_results = play_all_pairs(env, all_policies, model_names, num_episodes=10)
# Out:
# Wall time: 5min 49s

# %% [markdown]
# ## Plot results

# %%
for team in ['thieves', 'guardians']:
    aggregates_df, team_rewards, models_order = plot_team_aggregates(all_results, team)
    display(aggregates_df)
    plot_boxplot(team_rewards, models_order, team)
# Out:
# <style  type="text/css" >
#     #T_e648fdca_1487_11ea_afc9_ccb0daf20494row0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 100.0%, transparent 100.0%);
#         }    #T_e648fdca_1487_11ea_afc9_ccb0daf20494row0_col1 {
#             width:  10em;
#              height:  80%;
#         }    #T_e648fdca_1487_11ea_afc9_ccb0daf20494row1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 85.3%, transparent 85.3%);
#         }    #T_e648fdca_1487_11ea_afc9_ccb0daf20494row1_col1 {
#             width:  10em;
#              height:  80%;
#         }    #T_e648fdca_1487_11ea_afc9_ccb0daf20494row2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 54.9%, transparent 54.9%);
#         }    #T_e648fdca_1487_11ea_afc9_ccb0daf20494row2_col1 {
#             width:  10em;
# ...

# %% [markdown]
# ## Get results

# %%
# Read models from disk
all_policies, model_names = read_models('../abc/grids')

# %% [markdown]
# ❗ Make sure all models in `models_dir` were trained on the same environment that is instantiated below:

# %%
# Re-instantiate the environment
config = Config()
config.scenario = '9x9,2v2,pacman-1'
config.state_representation = 'grid'

env = TGEnv(config)

# %%
# %%time
# Have all thieves play against all guardians
all_results = play_all_pairs(env, all_policies, model_names, num_episodes=10)
# Out:
# Wall time: 6min 1s

# %% [markdown]
# ## Plot results

# %%
for team in ['thieves', 'guardians']:
    aggregates_df, team_rewards, models_order = plot_team_aggregates(all_results, team)
    display(aggregates_df)
    plot_boxplot(team_rewards, models_order, team)
# Out:
# <style  type="text/css" >
#     #T_f946bbb0_1488_11ea_9855_ccb0daf20494row0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 100.0%, transparent 100.0%);
#         }    #T_f946bbb0_1488_11ea_9855_ccb0daf20494row0_col1 {
#             width:  10em;
#              height:  80%;
#         }    #T_f946bbb0_1488_11ea_9855_ccb0daf20494row1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 100.0%, transparent 100.0%);
#         }    #T_f946bbb0_1488_11ea_9855_ccb0daf20494row1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 50.0%, transparent 50.0%);
#         }    #T_f946bbb0_1488_11ea_9855_ccb0daf20494row2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 88.5%, transparent 88.5%);
# ...
